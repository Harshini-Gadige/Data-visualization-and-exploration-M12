# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/harshini/Desktop/Thinkful/Data/book.csv", encoding = "ISO-8859-1")
df.head()
# Out:
#               PMID/PMCID Publisher           Journal title  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                        Article title  \
# 0  Reduced parahippocampal cortical thickness in ...
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 0                                              £0.00
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# ...

# %%
df.isnull().sum()
# Out:
# PMID/PMCID                                             199
# Publisher                                                0
# Journal title                                            1
# Article title                                            0
# COST (£) charged to Wellcome (inc VAT when charged)      0
# dtype: int64

# %%
no_null = df.dropna()
no_null.head()
# Out:
#               PMID/PMCID Publisher                   Journal title  \
# 1             PMC3679557       ACS               Biomacromolecules
# 2  23043264  PMC3506128        ACS                      J Med Chem
# 3    23438330 PMC3646402       ACS                      J Med Chem
# 4   23438216 PMC3601604        ACS                      J Org Chem
# 5             PMC3579457       ACS  Journal of Medicinal Chemistry
#
#                                        Article title  \
# 1  Structural characterization of a Model Gram-ne...
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...
# 3  Orvinols with mixed kappa/mu opioid receptor a...
# 4  Regioselective opening of myo-inositol orthoes...
# 5  Comparative Structural and Functional Studies ...
#
#   COST (£) charged to Wellcome (inc VAT when charged)
# 1                                           £2381.04
# 2                                            £642.56
# 3                                            £669.64
# ...

# %%
no_null['COST (£) charged to Wellcome (inc VAT when charged)'] = no_null['COST (£) charged to Wellcome (inc VAT when charged)'].str.replace('£','')
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#data['COST (£) charged to Wellcome (inc VAT when charged)'].astype(float)
no_null['COST (£) charged to Wellcome (inc VAT when charged)'] = pd.to_numeric(no_null['COST (£) charged to Wellcome (inc VAT when charged)'],errors='coerce')
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
no_null[no_null['Journal title'] == 'Proceedings of the National Academy of Sciences']
# Out:
#                        PMID/PMCID  \
# 429                       2766312
# 430                    PMC3511132
# 431                       3704016
# 1005     PMCID:\n    PMC3670340\n
# 1006     PMCID:\n    PMC3479458\n
# 1007       PMCID:\n    PMC3529010
# 1008                   PMC3479523
# 1009                   PMC3538261
# 1010                   PMC3557024
# 1011                      3666720
# 1012       PMCID:\n    PMC3619373
# 1013            PMCID: PMC3587277
# 1014                      3752214
# 1018         23213245 PMC3529034
# 1023            PMCID: PMC3503170
# 1024  PMID: 23319650  PMC3562850
# 1025      PMID: 23650371 23650371
# 1311                      3396515
# 1312          23341602 PMC3568321
#
#                                               Publisher  \
# 429                          Dartmouth Journal Services
# 430                          Dartmouth Journal Services
# 431                          Dartmouth Journal Services
# ...

# %%
no_null['Journal title'] = no_null['Journal title'].str.replace('PNAS','Proceedings of the National Academy of Sciences')
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
no_null
# Out:
#                             PMID/PMCID  \
# 1                           PMC3679557
# 2                23043264  PMC3506128
# 3                  23438330 PMC3646402
# 4                 23438216 PMC3601604
# 5                           PMC3579457
# 6                           PMC3709265
# 7                 23057412 PMC3495574
# 8                    PMCID: PMC3780468
# 9                    PMCID: PMC3621575
# 10                   PMCID: PMC3739413
# 11                   PMCID: PMC3530961
# 12                   PMCID: PMC3624797
# 13                          PMC3413243
# 14                          PMC3694353
# 15                          PMC3572711
# 16                            22610094
# 17                   PMCID: PMC3586974
# 18        23455506  PMCID: PMC3607399
# 19          PMID: 24015914 PMC3833349
# 20                       : PMC3805332
# 22            PMCID:\n    PMC3656742\n
# 23                      PMCID: 3584654
# 24                 22971149 PMC3466778
# ...

# %%
no_null[no_null['Journal title'] == 'PNAS']
# Out:
# Empty DataFrame
# Columns: [PMID/PMCID, Publisher, Journal title, Article title, COST (£) charged to Wellcome (inc VAT when charged)]
# Index: []
